# %%
import pandas as pd

df = pd.read_csv('repos.csv')

print(df.columns)
# Out:
# Index(['rank', 'item', 'repo_name', 'stars', 'forks', 'language', 'repo_url',
#        'username', 'issues', 'last_commit', 'description'],
#       dtype='object')
